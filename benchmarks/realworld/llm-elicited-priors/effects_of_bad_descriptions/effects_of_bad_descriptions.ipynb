# %% [markdown]
# # Testing the effects of bad task descriptions

# %%
import os
import json
import textwrap
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['text.usetex'] = False
import seaborn as sns
import matplotlib.transforms as transforms
import matplotlib.transforms as mpl_transforms

import sys
sys.path.append("../")
from llm_elicited_priors.utils import load_nested_dict_to_pandas
from llm_elicited_priors.plotting import graph_theme

# %%
width = 7.1413/0.75
colwidth = 3.433071
linewidth = 7.12598

# %%
RESULTS_PATH = "../results/elicitation/varied_descriptions"

# %%
results_files = [f for f in os.listdir(RESULTS_PATH) if f.endswith(".json")]
print("Loading files: ", "\n", "\n ".join(results_files))
results_dicts = [
    json.load(open(os.path.join(RESULTS_PATH, f), "r"))
    for f in results_files
]
# Out:
# Loading files:
#  prior_no_prior_results_fake_data_equation_feature_relationship_8.json
#  prior_no_prior_results_fake_data_one_feature_relationship_4.json
#  prior_no_prior_results_fake_data_two_feature_relationship_0.json
#  prior_no_prior_results_fake_data_adverserial_8.json
#  prior_no_prior_results_fake_data_two_feature_relationship_4.json
#  prior_no_prior_results_fake_data_adverserial_7.json
#  prior_no_prior_results_fake_data_uninformative_2.json
#  prior_no_prior_results_fake_data_one_feature_relationship_9.json
#  prior_no_prior_results_fake_data_equation_feature_relationship_0.json
#  prior_no_prior_results_fake_data_little_information_3.json
#  prior_no_prior_results_fake_data_uninformative_5.json
#  prior_no_prior_results_fake_data_one_feature_relationship_1.json
#  prior_no_prior_results_fake_data_uninformative_0.json
#  prior_no_prior_results_fake_data_three_feature_relationship_0.json
#  prior_no_prior_results_fake_data_uninformative_4.json
#  prior_no_prior_results_fake_data_three_feature_relationship_7.json
#  prior_no_prior_results_fake_data_little_information_5.json
#  prior_no_prior_results_fake_data_adverserial_2.json
#  prior_no_prior_results_fake_data_three_feature_relationship_6.json
#  prior_no_prior_results_fake_data_uninformative_6.json
#  prior_no_prior_results_fake_data_uninformative_1.json
#  prior_no_prior_results_fake_data_little_information_1.json
#  prior_no_prior_results_fake_data_uninformative_9.json
#  prior_no_prior_results_fake_data_three_feature_relationship_8.json
#  prior_no_prior_results_fake_data_little_information_7.json
#  prior_no_prior_results_fake_data_adverserial_6.json
#  prior_no_prior_results_fake_data_adverserial_1.json
#  prior_no_prior_results_fake_data_three_feature_relationship_2.json
#  prior_no_prior_results_fake_data_two_feature_relationship_9.json
#  prior_no_prior_results_fake_data_one_feature_relationship_2.json
#  prior_no_prior_results_fake_data_one_feature_relationship_8.json
#  prior_no_prior_results_fake_data_equation_feature_relationship_5.json
#  prior_no_prior_results_fake_data_equation_feature_relationship_2.json
#  prior_no_prior_results_fake_data_adverserial_0.json
#  prior_no_prior_results_fake_data_little_information_6.json
#  prior_no_prior_results_fake_data_adverserial_3.json
#  prior_no_prior_results_fake_data_one_feature_relationship_3.json
#  prior_no_prior_results_fake_data_three_feature_relationship_3.json
#  prior_no_prior_results_fake_data_equation_feature_relationship_3.json
#  prior_no_prior_results_fake_data_little_information_4.json
#  prior_no_prior_results_fake_data_uninformative_3.json
#  prior_no_prior_results_fake_data_little_information_9.json
#  prior_no_prior_results_fake_data_one_feature_relationship_5.json
#  prior_no_prior_results_fake_data_little_information_0.json
#  prior_no_prior_results_fake_data_equation_feature_relationship_9.json
#  prior_no_prior_results_fake_data_two_feature_relationship_5.json
#  prior_no_prior_results_fake_data_two_feature_relationship_7.json
#  prior_no_prior_results_fake_data_equation_feature_relationship_6.json
#  prior_no_prior_results_fake_data_three_feature_relationship_9.json
#  prior_no_prior_results_fake_data_equation_feature_relationship_7.json
#  prior_no_prior_results_fake_data_two_feature_relationship_2.json
#  prior_no_prior_results_fake_data_three_feature_relationship_4.json
#  prior_no_prior_results_fake_data_adverserial_5.json
#  prior_no_prior_results_fake_data_adverserial_4.json
#  prior_no_prior_results_fake_data_adverserial_9.json
#  prior_no_prior_results_fake_data_uninformative_7.json
#  prior_no_prior_results_fake_data_two_feature_relationship_8.json
#  prior_no_prior_results_fake_data_equation_feature_relationship_1.json
#  prior_no_prior_results_fake_data_one_feature_relationship_7.json
#  prior_no_prior_results_fake_data_two_feature_relationship_6.json
#  prior_no_prior_results_fake_data_one_feature_relationship_0.json
#  prior_no_prior_results_fake_data_three_feature_relationship_1.json
#  prior_no_prior_results_fake_data_two_feature_relationship_1.json
#  prior_no_prior_results_fake_data_equation_feature_relationship_4.json
#  prior_no_prior_results_fake_data_two_feature_relationship_3.json
#  prior_no_prior_results_fake_data_one_feature_relationship_6.json
#  prior_no_prior_results_fake_data_little_information_2.json
#  prior_no_prior_results_fake_data_little_information_8.json
#  prior_no_prior_results_fake_data_three_feature_relationship_5.json
#  prior_no_prior_results_fake_data_uninformative_8.json

# %%
results_dfs = [
    load_nested_dict_to_pandas(
        results_dict, 
        level_names=[
            "dataset", "description_type", "run", "n_data_points_seen", "prior_type"
        ]
    ).assign(results_file_name=results_file_name)
    
    for results_dict, results_file_name in zip(results_dicts, results_files)
]

results_df = pd.concat(
    results_dfs
).astype(
    {
        "n_data_points_seen": int,
    }
)

# %%
dataset_metric_to_plot = {
    "fake_data": "mse",
}

dataset_rename = {
    "fake_data": r"$y = 2 x_1 - x_2 + x_3$",
}


metric_results = (
    results_df
    # get the correct metric for each dataset
    .assign(
        metrics_to_plot=lambda df: (
            df.apply(
                lambda row: row[dataset_metric_to_plot[row["dataset"]]],
                axis=1
            )
        )
    )
    .assign(
        metrics_to_plot=lambda x: x["metrics_to_plot"].apply(
            lambda x: np.array(x).reshape(-1)),
    )
    .set_index(["dataset", "description_type", "n_data_points_seen", "prior_type", "run"])
    [["metrics_to_plot"]]
    .assign(sample=lambda x: x["metrics_to_plot"].apply(lambda x: np.arange(len(x))))
    .explode(["metrics_to_plot", "sample"])
    .set_index("sample", append=True)
    .reset_index()
    .reset_index(drop=True)
    .replace({"dataset": dataset_rename})
)

# %%
metric_results_line_plot = (
    metric_results
    .loc[lambda df: df["n_data_points_seen"].isin([5, 10, 20, 30])]
    .groupby(["dataset", "n_data_points_seen", "description_type", "run"])
    [["metrics_to_plot"]]
    .mean()
    .reset_index()
)

# %%
description_nice_names = {
    "adverserial": "Adverserial",
    "uninformative": "Uninformative",
    "little_information": "Linear relationship",
    "one_feature_relationship": "One feature relationship",
    "two_feature_relationship": "Two feature relationships",
    "three_feature_relationship": "Three feature relationships",
    "equation_feature_relationship": "Full equation",
}

description_order = [
    "Uninformative",
    "Linear relationship",
    "One feature relationship",
    "Two feature relationships",
    "Three feature relationships",
    "Full equation",
]

description_colour = {
    "Uninformative": "xkcd:bright orange",
    "Linear relationship": (0.94291042, 0.37549479, 0.26369821),
    "One feature relationship": (0.7965014, 0.10506637, 0.31063031),
    "Two feature relationships": (0.51728314, 0.1179558, 0.35453252),
    "Three feature relationships": (0.24525608, 0.10497384, 0.26395596),
    "Full equation": 'xkcd:bright blue',
}


fontsize=14

dataset = r"$y = 2 x_1 - x_2 + x_3$"

with graph_theme():
    plt.close()

    fig, ax = plt.subplots(
        1, 1, 
        figsize=(2*colwidth, 2*0.8*colwidth)
    )

    ax = sns.lineplot(
        data=(
            metric_results_line_plot
            .query("dataset == @dataset")
            .assign(
                metrics_to_plot=lambda x: 
                np.log10(x["metrics_to_plot"].astype(float)) 
            )
            .replace({"description_type": description_nice_names})
            .loc[lambda x : x["description_type"].isin(description_order)]
        ),
        x="n_data_points_seen",
        y="metrics_to_plot",
        hue="description_type",
        hue_order=description_order,
        style="description_type",
        markers=False,
        style_order=description_order[::-1],
        alpha=0.7,
        err_style="bars",
        errorbar=("ci", 95),
        err_kws=dict(
            capsize=2,
            capthick=1.5,
            elinewidth=1.5,
            linewidth=1.5,
        ),
        dashes=[
            (1, 0),
            (5, 1),
            (4, 1),
            (3, 1),
            (2, 1),
            (1, 0),
        ],
        markersize=7,
        linewidth=2,
        ax=ax,
        legend=True,
        palette=description_colour,
    )

    ax.set_ylabel(r"$\log_{10}$ MSE", fontsize=fontsize)
    ax.set_xlabel("Number of training examples", fontsize=fontsize)
    ax.tick_params(axis="both", labelsize=fontsize)
    ax.set_title("", fontsize=fontsize)

    sns.move_legend(
        ax,
        "upper right",
        bbox_to_anchor=(0.99, 0.99),
        fontsize=fontsize,
        title="",
        title_fontsize=fontsize,
        frameon=False,
    )

    fig.subplots_adjust(
        wspace=0.35,
        left=0.12,
        right=0.99,
        top=0.98,
        bottom=0.1,
    )

    fig.savefig(
        "../results/elicitation_varied_descriptions_results_lineplot.pdf",
    )
    fig.savefig(
        "../results/elicitation_varied_descriptions_results_lineplot.svg",
    )

    plt.show()

# %% [markdown]
# ## Looking at some of the priors:

# %%
PRIORS_DIR = Path("../priors/elicitation/varied_descriptions")

prior_files = [
    f
    for f in os.listdir(PRIORS_DIR)
    if f.startswith(f"fake_data_little_information")
]
priors = []
for prior_file in prior_files:
    prior = np.load(os.path.join(PRIORS_DIR, prior_file))
    priors.append(prior)

priors = np.stack(priors)

# %%
priors.mean(axis=0).round(2).astype(str)
# Out:
# array([['0.0', '1.0'],
#        ['0.5', '0.12'],
#        ['-0.32', '0.08'],
#        ['0.56', '0.14']], dtype='<U32')

# %%
priors.std(axis=0).round(2).astype(str)
# Out:
# array([['0.0', '0.0'],
#        ['0.11', '0.05'],
#        ['0.08', '0.06'],
#        ['0.26', '0.09']], dtype='<U32')

# %% [markdown]
# ## What do the priors look like for the task descriptions?

# %%
import pymc as pm

# %%
PRIORS_DIR = Path("../priors/elicitation/varied_descriptions")

prior_files = [
    f
    for f in os.listdir(PRIORS_DIR)
]

prior_types = {f.split("fake_data_")[1].split("_prior")[0] for f in  prior_files}

priors_dict = {pt: [] for pt in prior_types}
for prior_file in prior_files:
    prior = np.load(os.path.join(PRIORS_DIR, prior_file))
    prior_type = prior_file.split("fake_data_")[1].split("_prior")[0]
    priors_dict[prior_type].append(prior)

priors_dict = {pt: np.stack(priors_dict[pt]) for pt in prior_types}
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/Project/reactive_nb/kernels/nnb/shell/interactiveshell.py:472, in NnbInteractiveShell.run_cell_async(self, raw_cell, store_history, silent, shell_futures, cell_id, **kwargs)
#     470 else:
#     471     with save_number_of_currently_executing_cell():
# --> 472         ret = await self._nnb_run_cell(
#     473             raw_cell,
#     474             store_history=store_history,
#     475             shell_futures=shell_futures,
#     476             **kwargs,
#     477         )
#     478 return ret
#
# File ~/Project/reactive_nb/kernels/nnb/shell/interactiveshell.py:533, in NnbInteractiveShell._nnb_run_cell(self, raw_cell, store_history, shell_futures, **kwargs)
#     531     debug_log(f"  [nnb] not tracking exec {_mem_exec_id} (import-only/shell cell)")
#     532 with _track_ctx:
# --> 533     ret = await super().run_cell_async(
#     534         cell.raw_cell if has_transformed_cell else transformed_cell,
#     535         store_history=store_history,
#     536         silent=False,
#     537         shell_futures=shell_futures,
#     538         **self._filter_super_kwargs(
#     539             self._super_run_cell_async_param_names, kwargs
#     540         ),
#     541     )
#     542 cell.error_in_exec = ret.error_in_exec
#     543 if is_already_recording_output:
#
# File /usr/lib/python3.12/ast.py:230, in fix_missing_locations(node)
#     228     for child in iter_child_nodes(node):
#     229         _fix(child, lineno, col_offset, end_lineno, end_col_offset)
# --> 230 _fix(node, 1, 0, 1, 0)
#     231 return node
#
# File /usr/lib/python3.12/ast.py:229, in fix_missing_locations.<locals>._fix(node, lineno, col_offset, end_lineno, end_col_offset)
#     227         end_col_offset = node.end_col_offset
#     228 for child in iter_child_nodes(node):
# --> 229     _fix(child, lineno, col_offset, end_lineno, end_col_offset)
#
# File /usr/lib/python3.12/ast.py:229, in fix_missing_locations.<locals>._fix(node, lineno, col_offset, end_lineno, end_col_offset)
#     227         end_col_offset = node.end_col_offset
#     228 for child in iter_child_nodes(node):
# --> 229     _fix(child, lineno, col_offset, end_lineno, end_col_offset)
#
#     [... skipping similar frames: fix_missing_locations.<locals>._fix at line 229 (10 times)]
#
# File /usr/lib/python3.12/ast.py:229, in fix_missing_locations.<locals>._fix(node, lineno, col_offset, end_lineno, end_col_offset)
#     227         end_col_offset = node.end_col_offset
#     228 for child in iter_child_nodes(node):
# --> 229     _fix(child, lineno, col_offset, end_lineno, end_col_offset)
#
# File /usr/lib/python3.12/ast.py:228, in fix_missing_locations.<locals>._fix(node, lineno, col_offset, end_lineno, end_col_offset)
#     226     else:
#     227         end_col_offset = node.end_col_offset
# --> 228 for child in iter_child_nodes(node):
#     229     _fix(child, lineno, col_offset, end_lineno, end_col_offset)
#
# File /usr/lib/python3.12/ast.py:274, in iter_child_nodes(node)
#     269 def iter_child_nodes(node):
#     270     """
#     271     Yield all direct child nodes of *node*, that is, all fields that are nodes
#     272     and all items of fields that are lists of nodes.
#     273     """
# --> 274     for name, field in iter_fields(node):
#     275         if isinstance(field, AST):
#     276             yield field
#
# File /usr/lib/python3.12/ast.py:264, in iter_fields(node)
#     262 for field in node._fields:
#     263     try:
# --> 264         yield field, getattr(node, field)
#     265     except AttributeError:
#     266         pass
#
# KeyboardInterrupt:

# %%
# sampling prior parameters

prior_samples_dict = {}
for prior_type, priors in priors_dict.items():
    n_priors, n_features, _ = priors.shape
    with pm.Model() as model:

        w = pm.Dirichlet(
            'w', a=np.ones(n_priors), shape=(n_features, n_priors)
        )

        components = pm.Normal.dist(
            mu=priors[:, :, 0].T,
            sigma=priors[:, :, 1].T,
            shape=(n_features, n_priors)
        )

        theta = pm.Mixture(
            "theta",
            w=w,
            comp_dists=components,
        )

        prior_samples_pe = pm.sample_prior_predictive(random_seed=0)

    prior_samples_pe = (
        prior_samples_pe['prior']['theta']
        .to_numpy().squeeze()
    )

    prior_samples_dict[prior_type] = prior_samples_pe
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/Project/reactive_nb/kernels/nnb/shell/interactiveshell.py:472, in NnbInteractiveShell.run_cell_async(self, raw_cell, store_history, silent, shell_futures, cell_id, **kwargs)
#     470 else:
#     471     with save_number_of_currently_executing_cell():
# --> 472         ret = await self._nnb_run_cell(
#     473             raw_cell,
#     474             store_history=store_history,
#     475             shell_futures=shell_futures,
#     476             **kwargs,
#     477         )
#     478 return ret
#
# File ~/Project/reactive_nb/kernels/nnb/shell/interactiveshell.py:488, in NnbInteractiveShell._nnb_run_cell(self, raw_cell, store_history, shell_futures, **kwargs)
#     480 async def _nnb_run_cell(
#     481     self,
#     482     raw_cell: str,
#    (...)    486 ) -> ExecutionResult:
#     487     # Stage 1: pre-execute hook -- ipyflow's static analysis.
# --> 488     maybe_new_content = self.before_run_cell(
#     489         raw_cell, store_history=store_history, **kwargs
#     490     )
#     491     if maybe_new_content is not None:
#     492         raw_cell = maybe_new_content
#
# File ~/Project/reactive_nb/kernels/nnb/shell/interactiveshell.py:627, in NnbInteractiveShell.before_run_cell(self, cell_content, store_history, cell_id, **_kwargs)
#     624 # Stage 1 proper: static analysis precheck (populates
#     625 # cell.raw_static_parents via ipyflow's Cell.check_and_resolve_symbols).
#     626 if DataflowTracer in self.registered_tracers:
# --> 627     flow_._safety_precheck_cell(cell)
#     628     # cell.cell_ctr is assigned inside Cell.create_and_track above
#     629     # (this cell's new exec counter, not yet run) -- sync nnb's own
#     630     # Dag from raw_static_parents now, before this cell's code
#     631     # actually executes. See dag_sync.sync_before_cell_execution's
#     632     # own docstring for why this is safe and what it does/doesn't do.
#     633     sync_before_cell_execution(get_dag(), cell.cell_ctr)
#
# File ~/Project/reactive_nb/.venv/lib/python3.12/site-packages/ipyflow/flow.py:549, in NotebookFlow._safety_precheck_cell(self, cell)
#     546 for tracer in singletons.shell().registered_tracers:
#     547     # just make sure all tracers are initialized
#     548     tracer.instance()
# --> 549 checker_result = self.check_and_link_multiple_cells(
#     550     cells_to_check=[cell],
#     551     update_liveness_time_versions=self.mut_settings.static_slicing_enabled,
#     552 )
#     553 if cell.cell_id in checker_result.waiting_cells:
#     554     self.waiter_usage_detected = True
#
# File ~/Project/reactive_nb/.venv/lib/python3.12/site-packages/ipyflow/flow.py:539, in NotebookFlow.check_and_link_multiple_cells(self, cells_to_check, update_liveness_time_versions, last_executed_cell_id, allow_new_ready)
#     534 if (
#     535     DataflowTracer not in singletons.shell().registered_tracers
#     536     or not DataflowTracer.initialized()
#     537 ):
#     538     return result
# --> 539 return result.compute_frontend_checker_result(
#     540     cells_to_check=cells_to_check,
#     541     update_liveness_time_versions=update_liveness_time_versions,
#     542     last_executed_cell_id=last_executed_cell_id,
#     543 )
#
# File ~/Project/reactive_nb/.venv/lib/python3.12/site-packages/ipyflow/frontend.py:573, in FrontendCheckerResult.compute_frontend_checker_result(self, cells_to_check, update_liveness_time_versions, last_executed_cell_id)
#     571 cells_to_check = sorted(cells_to_check, key=lambda c: c.position)
#     572 for cell in cells_to_check:
# --> 573     self._check_one_cell(
#     574         cell,
#     575         update_liveness_time_versions,
#     576         last_executed_cell_pos,
#     577         waiting_symbols_by_cell_id,
#     578         killing_cell_ids_for_symbol,
#     579         phantom_cell_info,
#     580     )
#     582 self._compute_dag_based_waiters(cells_to_check)
#     583 self._compute_ready_making_cells(
#     584     waiting_symbols_by_cell_id,
#     585     killing_cell_ids_for_symbol,
#     586     last_executed_cell_id,
#     587 )
#
# File ~/Project/reactive_nb/.venv/lib/python3.12/site-packages/ipyflow/frontend.py:378, in FrontendCheckerResult._check_one_cell(self, cell, update_liveness_time_versions, last_executed_cell_pos, waiting_symbols_by_cell_id, killing_cell_ids_for_symbol, phantom_cell_info)
#     376 flow_ = flow()
#     377 try:
# --> 378     checker_result = cell.check_and_resolve_symbols(
#     379         update_liveness_time_versions=update_liveness_time_versions
#     380     )
#     381 except SyntaxError:
#     382     return None
#
# File ~/Project/reactive_nb/.venv/lib/python3.12/site-packages/ipyflow/data_model/cell.py:814, in Cell.check_and_resolve_symbols(self, update_liveness_time_versions)
#     805 def check_and_resolve_symbols(
#     806     self,
#     807     update_liveness_time_versions: bool = False,
#     808 ) -> CheckerResult:
#     809     (
#     810         live_symbol_refs,
#     811         dead_symbol_refs,
#     812         modified_symbol_refs,
#     813         update_liveness_time_versions,
# --> 814     ) = self._get_live_dead_modified_symbol_refs(update_liveness_time_versions)
#     815     with flow().override_child_cell(self):
#     816         (
#     817             live_resolved_symbols,
#     818             live_cells,
#    (...)    824             update_liveness_time_versions=update_liveness_time_versions,
#     825         )
#
# File ~/Project/reactive_nb/.venv/lib/python3.12/site-packages/ipyflow/data_model/cell.py:784, in Cell._get_live_dead_modified_symbol_refs(self, update_liveness_time_versions)
#     777 modified_symbol_refs: Set[SymbolRef] = set()
#     778 if self.override_live_refs is None and self.override_dead_refs is None:
#     779     (
#     780         live_symbol_refs,
#     781         dead_symbol_refs,
#     782         modified_symbol_refs,
#     783     ) = compute_live_dead_symbol_refs(
# --> 784         self.to_ast(),
#     785         scope=flow().global_scope,
#     786         include_killed_live=self.cell_ctr > 0,
#     787     )
#     788 else:
#     789     if self.override_live_refs is not None:
#
# File ~/Project/reactive_nb/.venv/lib/python3.12/site-packages/ipyflow/data_model/cell.py:672, in Cell.to_ast(self, override)
#     665     return self._cached_ast
#     666 if (
#     667     self._cached_ast is None
#     668     or self.last_ast_content is None
#     669     or len(self.last_ast_content) != len(self.current_content)
#     670     or self.last_ast_content != self.current_content
#     671 ):
# --> 672     path = self.make_ipython_name()
#     673     rewriter, content = self._rewriter_and_sanitized_content(path=path)
#     674     self._cached_ast = ast.parse(content)
#
# File ~/Project/reactive_nb/.venv/lib/python3.12/site-packages/ipyflow/data_model/cell.py:648, in Cell.make_ipython_name(self)
#     646 if "raw_code" in inspect.signature(cache).parameters:
#     647     kwargs["raw_code"] = self.raw_cell
# --> 648 return cache(self.transformed_cell, self.cell_ctr, **kwargs)
#
# File ~/Project/reactive_nb/.venv/lib/python3.12/site-packages/ipykernel/compiler.py:106, in XCachingCompiler.get_code_name(self, raw_code, code, number)
#     104 def get_code_name(self, raw_code, code, number):
#     105     """Get the code name."""
# --> 106     return get_file_name(raw_code)
#
# File ~/Project/reactive_nb/.venv/lib/python3.12/site-packages/ipykernel/compiler.py:91, in get_file_name(code)
#      89 cell_name = os.environ.get("IPYKERNEL_CELL_NAME")
#      90 if cell_name is None:
# ---> 91     name = murmur2_x86(code, get_tmp_hash_seed())
#      92     cell_name = get_tmp_directory() + os.sep + str(name) + ".py"
#      93 return cell_name
#
# File ~/Project/reactive_nb/.venv/lib/python3.12/site-packages/ipykernel/compiler.py:26, in murmur2_x86(data, seed)
#      24 k = (k * m) & 0xFFFFFFFF
#      25 k ^= k >> 24
# ---> 26 k = (k * m) & 0xFFFFFFFF
#      28 h = (h * m) & 0xFFFFFFFF
#      29 h ^= k
#
# KeyboardInterrupt:

# %%
prior_types_to_plot = [
    "one_feature_relationship",
    "two_feature_relationship",
    "three_feature_relationship",
]

description_colour = {
    "one_feature_relationship": (0.7965014, 0.10506637, 0.31063031),
    "two_feature_relationship": (0.51728314, 0.1179558, 0.35453252),
    "three_feature_relationship": (0.24525608, 0.10497384, 0.26395596),
}

description_nice_names = {
    "one_feature_relationship": "One feature relationship",
    "two_feature_relationship": "Two feature relationships",
    "three_feature_relationship": "Three feature relationships",
}


fontsize = 14
alpha = 0.7
hist_config = dict(
    alpha = alpha,
    bins=100,
    edgecolor = "black",
    linewidth = 0.0,
    stat = "density",
)

with graph_theme():
    plt.close()
    fig = plt.figure(
        figsize=(1.5*linewidth, 0.6*2*linewidth/1.618)
    )
    for prior_i, prior_type in enumerate(prior_types_to_plot):
        prior_samples_pe = prior_samples_dict[prior_type]
        
        for feature in range(n_features-1):

            ax = fig.add_subplot(
                len(prior_types_to_plot), 
                (n_features-1), 
                feature+1 + prior_i*len(prior_types_to_plot)
            )

            sns.histplot(
                prior_samples_pe[:, feature + 1], 
                color=description_colour[prior_type],
                ax=ax,
                **hist_config
            )

            if prior_i == 0:
                ax.set_title(f"Feature {feature + 1}", fontsize=fontsize)
            if feature == 0:
                ax.set_ylabel("Density", fontsize=fontsize)
                ax.set_yticks([1,2,3])
                ax.set_yticklabels([1,2,""])
            else:
                ax.set_ylabel("", fontsize=fontsize)
                ax.set_yticks([1,2,3])
                ax.set_yticklabels([])


            if prior_i == len(prior_types_to_plot) - 1:
                ax.set_xlabel(f"Parameter value", fontsize=fontsize)
                ax.set_xticks([-2, 0, 2])
            else:
                ax.set_xlabel("", fontsize=fontsize)
                ax.set_xticks([-2, 0, 2])
                ax.set_xticklabels([])

            ax.tick_params(axis="both", labelsize=fontsize)

            ax.set_xlim(-3, 3)
            ax.set_ylim(0, 2.8)


            median_param_value = np.median(prior_samples_pe[:, feature+1])

            ax.axvline(
                x=median_param_value, 
                linestyle="--", 
                color="xkcd:black",
            )

            trans = transforms.blended_transform_factory(ax.transData, ax.transAxes)

            if median_param_value > -0.5:
                ax.text(
                    median_param_value-0.25, 0.8, 
                    f"Median: {median_param_value:.1f}",
                    fontsize=fontsize,
                    transform=trans,
                    verticalalignment='center',
                    horizontalalignment='right',
                    bbox=dict(facecolor='white', alpha=0.5, edgecolor='black'),
                )
            else:
                ax.text(
                    median_param_value+0.25, 0.8, 
                    f"Median: {median_param_value:.1f}",
                    fontsize=fontsize,
                    transform=trans,
                    verticalalignment='center',
                    horizontalalignment='left',
                    bbox=dict(facecolor='white', alpha=0.5, edgecolor='black'),
                )
            
            if feature == 0:
                trans = mpl_transforms.blended_transform_factory(
                    fig.transFigure, ax.transAxes
                )
                fig.text(
                    0.01, 0.5,
                    '\n'.join(textwrap.wrap(description_nice_names[prior_type], 20)),
                    horizontalalignment='left',
                    verticalalignment='center',
                    transform=trans,
                    fontsize=fontsize,
                    rotation=90,
                    multialignment="center",
                    bbox=dict(
                        facecolor='white', 
                        alpha=0.75, 
                        edgecolor='black',
                        linewidth=0.5
                    ),
                )

            if prior_i == 1 and feature == 1:
                ax.axvline(
                    0, linestyle="--", color="xkcd:black"
                )
                ax.arrow(
                    -0.1, 1.5, -0.75, 0,
                    head_width=0.15,
                    head_length=0.2,
                    linewidth=2,
                    fc='xkcd:green',
                    ec='xkcd:green',
                    length_includes_head=True,
                )

            if prior_i == 2 and feature == 2:
                ax.axvline(
                    0, linestyle="--", color="xkcd:black"
                )
                ax.arrow(
                    0.1, 1.5, 0.75, 0,
                    head_width=0.15,
                    head_length=0.2,
                    linewidth=2,
                    fc='xkcd:green',
                    ec='xkcd:green',
                    length_includes_head=True,
                )

            if prior_i == 0 and feature == 2:
                ax.arrow(
                    3.45, 2.25, 0.0, -8,
                    head_width=0.15,
                    head_length=0.2,
                    linewidth=4,
                    fc='xkcd:purple',
                    ec='xkcd:purple',
                    length_includes_head=True,
                    clip_on=False,
                )
                ax.text(
                    3.75, 2.75-4.5, 
                    "Increasingly detailed expert information",
                    fontsize=fontsize,
                    verticalalignment='center',
                    horizontalalignment='center',
                    rotation=270,
                )


    fig.subplots_adjust(
        wspace=0.1,
        hspace=0.1,
        top=0.95,
        bottom=0.1,
        left=0.1,
        right=0.95,
    )

    fig.savefig(
        "../results/elicitation_varied_descriptions_prior_parameter_distribution.pdf",
    )
    fig.savefig(
        "../results/elicitation_varied_descriptions_prior_parameter_distribution.png",
        dpi=300,
    )


    plt.show()
# Out:
# KeyboardInterrupt
