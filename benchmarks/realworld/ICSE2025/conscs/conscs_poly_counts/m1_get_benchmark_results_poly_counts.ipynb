# %%
# %flow mode reactive

# %%
import sys
import os


import misc, data_structures, r1cs_utils
from utils import *

# %%
def run_and_log_and_count_poly(target_folder, file_path, log_path, log_path_with_contributions):  
    if not file_path.endswith('.r1cs'):
        return dict()
    
    if file_path in ['Main@main@circomlib.r1cs', 'Sha256_2@sha256_2@circomlib.r1cs', 'Sha256compression@sha256compression@circomlib.r1cs']:
        # extremely large, times out without finishing reading
        return dict()
    
    
    
    file_name = os.path.basename(file_path)
    base_name = file_name.split('.')[0]
    full_path = os.path.join(target_folder, file_path)
    target_file_path = full_path
    print(target_file_path)
    
    cur_d = dict()
    
    clear_data_structures()
    r1cs_circuit = parse_entire_circuit(target_file_path, print_all_circuits = 0)
    for cons in r1cs_circuit.all_constraints:
        cur_len = len(cons.terms) - 1
        cur_d[cur_len] = cur_d.get(cur_len, 0) + 1

    return cur_d

# %%
all_d = dict()
all_d_counts = dict()
log_path = ''
log_path_with_contributions = ''
for type_folder in ["utils"]:
    target_folder = os.path.join("../conscs_data/benchmarks/", type_folder)
    for file_path in os.listdir(target_folder):
        cur_d = run_and_log_and_count_poly(target_folder, file_path, log_path, log_path_with_contributions)
        assert file_path not in all_d
        all_d[file_path] = cur_d
        for k in cur_d:
            all_d_counts[k] = all_d_counts.get(k, 0) + cur_d[k]
# Out:
# ../benchmarks/utils/Switcher@switcher.r1cs
# read done
# 3 constraints, 4 inputs, 2 outputs.
# parse done
# ../benchmarks/utils/NAND@gates.r1cs
# read done
# 1 constraints, 3 inputs, 1 outputs.
# parse done
# ../benchmarks/utils/Poseidon@poseidon.r1cs
# read done
# 761 constraints, 3 inputs, 1 outputs.
# parse done
# ../benchmarks/utils/LessThan@comparators.r1cs
# read done
# 6 constraints, 3 inputs, 1 outputs.
# parse done
# ../benchmarks/utils/MontgomeryDouble@montgomery.r1cs
# read done
# 4 constraints, 3 inputs, 2 outputs.
# parse done
# ../benchmarks/utils/MiMC7@mimc.r1cs
# read done
# 8 constraints, 3 inputs, 1 outputs.
# parse done
# ../benchmarks/utils/IsZero@comparators.r1cs
# read done
# 2 constraints, 2 inputs, 1 outputs.
# parse done
# ../benchmarks/utils/NOT@gates.r1cs
# read done
# 1 constraints, 2 inputs, 1 outputs.
# parse done
# ../benchmarks/utils/GreaterEqThan@comparators.r1cs
# read done
# 9 constraints, 3 inputs, 1 outputs.
# parse done
# ../benchmarks/utils/Sigma@poseidon.r1cs
# read done
# 3 constraints, 2 inputs, 1 outputs.
# parse done
# ../benchmarks/utils/Multiplexer@multiplexer.r1cs
# read done
# 22 constraints, 6 inputs, 2 outputs.
# parse done
# ../benchmarks/utils/Segment@pedersen.r1cs
# read done
# 221 constraints, 11 inputs, 2 outputs.
# parse done
# ../benchmarks/utils/MontgomeryAdd@montgomery.r1cs
# read done
# 3 constraints, 5 inputs, 2 outputs.
# parse done
# ../benchmarks/utils/Num2BitsNeg@bitify.r1cs
# read done
# 6 constraints, 2 inputs, 2 outputs.
# parse done
# ../benchmarks/utils/Bits2Point_Strict@pointbits.r1cs
# read done
# 2589 constraints, 257 inputs, 2 outputs.
# parse done
# ../benchmarks/utils/Bits2Num_strict@bitify.r1cs
# read done
# 1031 constraints, 255 inputs, 1 outputs.
# parse done
# ../benchmarks/utils/SegmentMulFix@escalarmulfix.r1cs
# read done
# 250 constraints, 9 inputs, 4 outputs.
# parse done
# ../benchmarks/utils/EdDSAPoseidonVerifier@eddsaposeidon.r1cs
# read done
# 21239 constraints, 8 inputs, 0 outputs.
# parse done
# ../benchmarks/utils/XOR@gates.r1cs
# read done
# 1 constraints, 3 inputs, 1 outputs.
# parse done
# ../benchmarks/utils/Sign@sign.r1cs
# read done
# 521 constraints, 255 inputs, 1 outputs.
# parse done
# ../benchmarks/utils/EscalarMulAny@escalarmulany.r1cs
# read done
# 67 constraints, 5 inputs, 2 outputs.
# parse done
# ../benchmarks/utils/Decoder@multiplexer.r1cs
# read done
# 4 constraints, 2 inputs, 3 outputs.
# parse done
# ../benchmarks/utils/WindowMulFix@escalarmulfix.r1cs
# read done
# 90 constraints, 6 inputs, 4 outputs.
# parse done
# ../benchmarks/utils/Pedersen@pedersen_old.r1cs
# read done
# 100 constraints, 3 inputs, 2 outputs.
# parse done
# ../benchmarks/utils/IsEqual@comparators.r1cs
# read done
# 4 constraints, 3 inputs, 1 outputs.
# parse done
# ../benchmarks/utils/BabyPbk@babyjub.r1cs
# read done
# 10114 constraints, 2 inputs, 2 outputs.
# parse done
# ../benchmarks/utils/AliasCheck@aliascheck.r1cs
# read done
# 521 constraints, 255 inputs, 0 outputs.
# parse done
# ../benchmarks/utils/BinSum@binsum.r1cs
# read done
# 4 constraints, 5 inputs, 3 outputs.
# parse done
# ../benchmarks/utils/BabyDbl@babyjub.r1cs
# read done
# 12 constraints, 3 inputs, 2 outputs.
# parse done
# ../benchmarks/utils/Mux4@mux4.r1cs
# read done
# 42 constraints, 21 inputs, 1 outputs.
# parse done
# ../benchmarks/utils/Mux3@mux3.r1cs
# read done
# 22 constraints, 12 inputs, 1 outputs.
# parse done
# ../benchmarks/utils/OR@gates.r1cs
# read done
# 1 constraints, 3 inputs, 1 outputs.
# parse done
# ../benchmarks/utils/MultiMiMC7@mimc.r1cs
# read done
# 24 constraints, 4 inputs, 1 outputs.
# parse done
# ../benchmarks/utils/EdDSAMiMCVerifier@eddsamimc.r1cs
# read done
# 21737 constraints, 8 inputs, 0 outputs.
# parse done
# ../benchmarks/utils/ForceEqualIfEnabled@comparators.r1cs
# read done
# 4 constraints, 4 inputs, 0 outputs.
# parse done
# ../benchmarks/utils/MultiMux3@mux3.r1cs
# read done
# 19 constraints, 20 inputs, 2 outputs.
# parse done
# ../benchmarks/utils/MultiMux4@mux4.r1cs
# read done
# 38 constraints, 37 inputs, 2 outputs.
# parse done
# ../benchmarks/utils/Multiplexor2@escalarmulany.r1cs
# read done
# 2 constraints, 6 inputs, 2 outputs.
# parse done
# ../benchmarks/utils/CompConstant@compconstant.r1cs
# read done
# 266 constraints, 255 inputs, 1 outputs.
# parse done
# ../benchmarks/utils/Point2Bits_Strict@pointbits.r1cs
# read done
# 2838 constraints, 3 inputs, 256 outputs.
# parse done
# ../benchmarks/utils/Bits2Num@bitify.r1cs
# read done
# 1 constraints, 3 inputs, 1 outputs.
# parse done
# ../benchmarks/utils/BabyAdd@babyjub.r1cs
# read done
# 6 constraints, 5 inputs, 2 outputs.
# parse done
# ../benchmarks/utils/Window4@pedersen.r1cs
# read done
# 90 constraints, 7 inputs, 4 outputs.
# parse done
# ../benchmarks/utils/SegmentMulAny@escalarmulany.r1cs
# read done
# 58 constraints, 5 inputs, 4 outputs.
# parse done
# ../benchmarks/utils/Edwards2Montgomery@montgomery.r1cs
# read done
# 2 constraints, 3 inputs, 2 outputs.
# parse done
# ../benchmarks/utils/MiMCFeistel@mimcsponge.r1cs
# read done
# 8 constraints, 4 inputs, 2 outputs.
# parse done
# ../benchmarks/utils/BabyCheck@babyjub.r1cs
# read done
# 3 constraints, 3 inputs, 0 outputs.
# parse done
# ../benchmarks/utils/LessEqThan@comparators.r1cs
# read done
# 9 constraints, 3 inputs, 1 outputs.
# parse done
# ../benchmarks/utils/Mux1@mux1.r1cs
# read done
# 5 constraints, 4 inputs, 1 outputs.
# parse done
# ../benchmarks/utils/Pedersen@pedersen.r1cs
# read done
# 114 constraints, 3 inputs, 2 outputs.
# parse done
# ../benchmarks/utils/BinSub@binsub.r1cs
# read done
# 4 constraints, 5 inputs, 2 outputs.
# parse done
# ../benchmarks/utils/MultiMux1@mux1.r1cs
# read done
# 2 constraints, 6 inputs, 2 outputs.
# parse done
# ../benchmarks/utils/Montgomery2Edwards@montgomery.r1cs
# read done
# 2 constraints, 3 inputs, 2 outputs.
# parse done
# ../benchmarks/utils/MultiMux2@mux2.r1cs
# read done
# 11 constraints, 11 inputs, 2 outputs.
# parse done
# ../benchmarks/utils/GreaterThan@comparators.r1cs
# read done
# 9 constraints, 3 inputs, 1 outputs.
# parse done
# ../benchmarks/utils/Num2Bits@bitify.r1cs
# read done
# 3 constraints, 2 inputs, 2 outputs.
# parse done
# ../benchmarks/utils/EscalarProduct@multiplexer.r1cs
# read done
# 3 constraints, 5 inputs, 1 outputs.
# parse done
# ../benchmarks/utils/BitElementMulAny@escalarmulany.r1cs
# read done
# 24 constraints, 6 inputs, 4 outputs.
# parse done
# ../benchmarks/utils/EdDSAVerifier@eddsa.r1cs
# read done
# 42920 constraints, 771 inputs, 0 outputs.
# parse done
# ../benchmarks/utils/MultiAND@gates.r1cs
# read done
# 4 constraints, 3 inputs, 1 outputs.
# parse done
# ../benchmarks/utils/NOR@gates.r1cs
# read done
# 1 constraints, 3 inputs, 1 outputs.
# parse done
# ../benchmarks/utils/Mux2@mux2.r1cs
# read done
# 13 constraints, 7 inputs, 1 outputs.
# parse done
# ../benchmarks/utils/Num2Bits_strict@bitify.r1cs
# read done
# 1285 constraints, 2 inputs, 254 outputs.
# parse done
# ../benchmarks/utils/AND@gates.r1cs
# read done
# 1 constraints, 3 inputs, 1 outputs.
# parse done
# ../benchmarks/utils/EdDSAMiMCSpongeVerifier@eddsamimcsponge.r1cs
# read done
# 24316 constraints, 8 inputs, 0 outputs.
# parse done
# ../benchmarks/utils/MiMCSponge@mimcsponge.r1cs
# read done
# 35 constraints, 4 inputs, 2 outputs.
# parse done
# ../benchmarks/core/Bits2Num@bitify@circomlib_64.r1cs
# read done
# 1 constraints, 65 inputs, 1 outputs.
# parse done
# ../benchmarks/core/SMTHash2@smthash_poseidon@circomlib.r1cs
# read done
# 764 constraints, 3 inputs, 1 outputs.
# parse done
# ../benchmarks/core/Num2Bits@bitify@circomlib_253.r1cs
# read done
# 254 constraints, 2 inputs, 253 outputs.
# parse done
# ../benchmarks/core/Mux4@mux4@circomlib.r1cs
# read done
# 42 constraints, 21 inputs, 1 outputs.
# parse done
# ../benchmarks/core/IsEqual@comparators@circomlib.r1cs
# read done
# 4 constraints, 3 inputs, 1 outputs.
# parse done
# ../benchmarks/core/Window4@pedersen@circomlib.r1cs
# read done
# 90 constraints, 7 inputs, 4 outputs.
# parse done
# ../benchmarks/core/SMTVerifierSM@smtverifiersm@circomlib.r1cs
# read done
# 7 constraints, 9 inputs, 5 outputs.
# parse done
# ../benchmarks/core/Pedersen@pedersen@circomlib_16.r1cs
# read done
# 471 constraints, 17 inputs, 2 outputs.
# parse done
# ../benchmarks/core/IsZero@comparators@circomlib.r1cs
# read done
# 2 constraints, 2 inputs, 1 outputs.
# parse done
# ../benchmarks/core/Mux2@mux2@circomlib.r1cs
# read done
# 13 constraints, 7 inputs, 1 outputs.
# parse done
# ../benchmarks/core/AND@gates@circomlib.r1cs
# read done
# 1 constraints, 3 inputs, 1 outputs.
# parse done
# ../benchmarks/core/WindowMulFix@escalarmulfix@circomlib.r1cs
# read done
# 90 constraints, 6 inputs, 4 outputs.
# parse done
# ../benchmarks/core/Pedersen@pedersen_old@circomlib_254.r1cs
# read done
# 6152 constraints, 255 inputs, 2 outputs.
# parse done
# ../benchmarks/core/GreaterThan@comparators@circomlib_8.r1cs
# read done
# 15 constraints, 3 inputs, 1 outputs.
# parse done
# ../benchmarks/core/Bits2Point@pointbits@circomlib.r1cs
# read done
# 0 constraints, 257 inputs, 2 outputs.
# parse done
# ../benchmarks/core/Mux3@mux3@circomlib.r1cs
# read done
# 22 constraints, 12 inputs, 1 outputs.
# parse done
# ../benchmarks/core/Bits2Num@bitify@circomlib_1.r1cs
# read done
# 1 constraints, 2 inputs, 1 outputs.
# parse done
# ../benchmarks/core/Num2BitsNeg@bitify@circomlib_254.r1cs
# read done
# 258 constraints, 2 inputs, 254 outputs.
# parse done
# ../benchmarks/core/MontgomeryAdd@montgomery@circomlib.r1cs
# read done
# 3 constraints, 5 inputs, 2 outputs.
# parse done
# ../benchmarks/core/Bits2Num_strict@bitify@circomlib.r1cs
# read done
# 1031 constraints, 255 inputs, 1 outputs.
# parse done
# ../benchmarks/core/Bits2Point_Strict@pointbits@circomlib.r1cs
# read done
# 2589 constraints, 257 inputs, 2 outputs.
# parse done
# ../benchmarks/core/Bits2Num@bitify@circomlib_253.r1cs
# read done
# 1 constraints, 254 inputs, 1 outputs.
# parse done
# ../benchmarks/core/Num2Bits@bitify@circomlib_8.r1cs
# read done
# 9 constraints, 2 inputs, 8 outputs.
# parse done
# ../benchmarks/core/SMTHash1@smthash_mimc@circomlib.r1cs
# read done
# 740 constraints, 3 inputs, 1 outputs.
# parse done
# ../benchmarks/core/Pedersen@pedersen@circomlib_8.r1cs
# read done
# 233 constraints, 9 inputs, 2 outputs.
# parse done
# ../benchmarks/core/EdDSAMiMCSpongeVerifier@eddsamimcsponge@circomlib.r1cs
# read done
# 24316 constraints, 8 inputs, 0 outputs.
# parse done
# ../benchmarks/core/SMTProcessorLevel@smtprocessorlevel@circomlib.r1cs
# read done
# 1502 constraints, 13 inputs, 2 outputs.
# parse done
# ../benchmarks/core/EdDSAPoseidonVerifier@eddsaposeidon@circomlib.r1cs
# read done
# 21239 constraints, 8 inputs, 0 outputs.
# parse done
# ../benchmarks/core/BinSum@binsum@circomlib_32_2.r1cs
# read done
# 34 constraints, 65 inputs, 33 outputs.
# parse done
# ../benchmarks/core/Bits2Num@bitify@circomlib_32.r1cs
# read done
# 1 constraints, 33 inputs, 1 outputs.
# parse done
# ../benchmarks/core/Num2Bits@bitify@circomlib_16.r1cs
# read done
# 17 constraints, 2 inputs, 16 outputs.
# parse done
# ../benchmarks/core/Mux1@mux1@circomlib.r1cs
# read done
# 5 constraints, 4 inputs, 1 outputs.
# parse done
# ../benchmarks/core/Bits2Num@bitify@circomlib_254.r1cs
# read done
# 1 constraints, 255 inputs, 1 outputs.
# parse done
# ../benchmarks/core/LessEqThan@comparators@circomlib_32.r1cs
# read done
# 39 constraints, 3 inputs, 1 outputs.
# parse done
# ../benchmarks/core/GreaterThan@comparators@circomlib_32.r1cs
# read done
# 39 constraints, 3 inputs, 1 outputs.
# parse done
# ../benchmarks/core/Pedersen@pedersen@circomlib_128.r1cs
# read done
# 3803 constraints, 129 inputs, 2 outputs.
# parse done
# ../benchmarks/core/Montgomery2Edwards@montgomery@circomlib.r1cs
# read done
# 2 constraints, 3 inputs, 2 outputs.
# parse done
# ../benchmarks/core/Num2BitsNeg@bitify@circomlib_253.r1cs
# read done
# 257 constraints, 2 inputs, 253 outputs.
# parse done
# ../benchmarks/core/Pedersen@pedersen@circomlib_256.r1cs
# read done
# 7614 constraints, 257 inputs, 2 outputs.
# parse done
# ../benchmarks/core/BinSum@binsum@circomlib_32_5.r1cs
# read done
# 36 constraints, 161 inputs, 35 outputs.
# parse done
# ../benchmarks/core/NOR@gates@circomlib.r1cs
# read done
# 1 constraints, 3 inputs, 1 outputs.
# parse done
# ../benchmarks/core/Num2BitsNeg@bitify@circomlib_8.r1cs
# read done
# 12 constraints, 2 inputs, 8 outputs.
# parse done
# ../benchmarks/core/BinSub@binsub@circomlib_16.r1cs
# read done
# 18 constraints, 33 inputs, 16 outputs.
# parse done
# ../benchmarks/core/AliasCheck@aliascheck@circomlib.r1cs
# read done
# 521 constraints, 255 inputs, 0 outputs.
# parse done
# ../benchmarks/core/SMTHash1@smthash_poseidon@circomlib.r1cs
# read done
# 930 constraints, 3 inputs, 1 outputs.
# parse done
# ../benchmarks/core/Pedersen@pedersen_old@circomlib_16.r1cs
# read done
# 390 constraints, 17 inputs, 2 outputs.
# parse done
# ../benchmarks/core/Multiplexor2@escalarmulany@circomlib.r1cs
# read done
# 2 constraints, 6 inputs, 2 outputs.
# parse done
# ../benchmarks/core/Num2BitsNeg@bitify@circomlib_16.r1cs
# read done
# 20 constraints, 2 inputs, 16 outputs.
# parse done
# ../benchmarks/core/Num2Bits@bitify@circomlib_254.r1cs
# read done
# 255 constraints, 2 inputs, 254 outputs.
# parse done
# ../benchmarks/core/GreaterEqThan@comparators@circomlib_16.r1cs
# read done
# 23 constraints, 3 inputs, 1 outputs.
# parse done
# ../benchmarks/core/Pedersen@pedersen_old@circomlib_1.r1cs
# read done
# 99 constraints, 2 inputs, 2 outputs.
# parse done
# ../benchmarks/core/NAND@gates@circomlib.r1cs
# read done
# 1 constraints, 3 inputs, 1 outputs.
# parse done
# ../benchmarks/core/Sigma@poseidon_old@circomlib.r1cs
# read done
# 3 constraints, 2 inputs, 1 outputs.
# parse done
# ../benchmarks/core/Sign@sign@circomlib.r1cs
# read done
# 521 constraints, 255 inputs, 1 outputs.
# parse done
# ../benchmarks/core/BabyAdd@babyjub@circomlib.r1cs
# read done
# 6 constraints, 5 inputs, 2 outputs.
# parse done
# ../benchmarks/core/Pedersen@pedersen_old@circomlib_253.r1cs
# read done
# 6151 constraints, 254 inputs, 2 outputs.
# parse done
# ../benchmarks/core/Num2Bits@bitify@circomlib_64.r1cs
# read done
# 65 constraints, 2 inputs, 64 outputs.
# parse done
# ../benchmarks/core/Pedersen@pedersen@circomlib_254.r1cs
# read done
# 7614 constraints, 255 inputs, 2 outputs.
# parse done
# ../benchmarks/core/Num2Bits@bitify@circomlib_1.r1cs
# read done
# 2 constraints, 2 inputs, 1 outputs.
# parse done
# ../benchmarks/core/Pedersen@pedersen@circomlib_1.r1cs
# read done
# 114 constraints, 2 inputs, 2 outputs.
# parse done
# ../benchmarks/core/Edwards2Montgomery@montgomery@circomlib.r1cs
# read done
# 2 constraints, 3 inputs, 2 outputs.
# parse done
# ../benchmarks/core/Bits2Num@bitify@circomlib_256.r1cs
# read done
# 1 constraints, 257 inputs, 1 outputs.
# parse done
# ../benchmarks/core/Pedersen@pedersen@circomlib_32.r1cs
# read done
# 947 constraints, 33 inputs, 2 outputs.
# parse done
# ../benchmarks/core/BabyPbk@babyjub@circomlib.r1cs
# read done
# 10114 constraints, 2 inputs, 2 outputs.
# parse done
# ../benchmarks/core/Bits2Num@bitify@circomlib_128.r1cs
# read done
# 1 constraints, 129 inputs, 1 outputs.
# parse done
# ../benchmarks/core/Bits2Num@bitify@circomlib_8.r1cs
# read done
# 1 constraints, 9 inputs, 1 outputs.
# parse done
# ../benchmarks/core/ForceEqualIfEnabled@comparators@circomlib.r1cs
# read done
# 4 constraints, 4 inputs, 0 outputs.
# parse done
# ../benchmarks/core/Num2Bits@bitify@circomlib_128.r1cs
# read done
# 129 constraints, 2 inputs, 128 outputs.
# parse done
# ../benchmarks/core/BabyCheck@babyjub@circomlib.r1cs
# read done
# 3 constraints, 3 inputs, 0 outputs.
# parse done
# ../benchmarks/core/EdDSAMiMCVerifier@eddsamimc@circomlib.r1cs
# read done
# 21737 constraints, 8 inputs, 0 outputs.
# parse done
# ../benchmarks/core/Num2Bits@bitify@circomlib_256.r1cs
# read done
# 257 constraints, 2 inputs, 256 outputs.
# parse done
# ../benchmarks/core/NOT@gates@circomlib.r1cs
# read done
# 1 constraints, 2 inputs, 1 outputs.
# parse done
# ../benchmarks/core/XOR@gates@circomlib.r1cs
# read done
# 1 constraints, 3 inputs, 1 outputs.
# parse done
# ../benchmarks/core/Pedersen@pedersen@circomlib_64.r1cs
# read done
# 1899 constraints, 65 inputs, 2 outputs.
# parse done
# ../benchmarks/core/BabyDbl@babyjub@circomlib.r1cs
# read done
# 12 constraints, 3 inputs, 2 outputs.
# parse done
# ../benchmarks/core/Num2Bits@bitify@circomlib_32.r1cs
# read done
# 33 constraints, 2 inputs, 32 outputs.
# parse done
# ../benchmarks/core/Sigma@poseidon@circomlib.r1cs
# read done
# 3 constraints, 2 inputs, 1 outputs.
# parse done
# ../benchmarks/core/Bits2Num@bitify@circomlib_16.r1cs
# read done
# 1 constraints, 17 inputs, 1 outputs.
# parse done
# ../benchmarks/core/Num2Bits_strict@bitify@circomlib.r1cs
# read done
# 1285 constraints, 2 inputs, 254 outputs.
# parse done
# ../benchmarks/core/Pedersen@pedersen_old@circomlib_8.r1cs
# read done
# 198 constraints, 9 inputs, 2 outputs.
# parse done
# ../benchmarks/core/SMTHash2@smthash_mimc@circomlib.r1cs
# read done
# 740 constraints, 3 inputs, 1 outputs.
# parse done
# ../benchmarks/core/T2@t2@circomlib.r1cs
# read done
# 706 constraints, 97 inputs, 32 outputs.
# parse done
# ../benchmarks/core/LessEqThan@comparators@circomlib_16.r1cs
# read done
# 23 constraints, 3 inputs, 1 outputs.
# parse done
# ../benchmarks/core/GreaterEqThan@comparators@circomlib_8.r1cs
# read done
# 15 constraints, 3 inputs, 1 outputs.
# parse done
# ../benchmarks/core/GreaterThan@comparators@circomlib_16.r1cs
# read done
# 23 constraints, 3 inputs, 1 outputs.
# parse done
# ../benchmarks/core/MontgomeryDouble@montgomery@circomlib.r1cs
# read done
# 4 constraints, 3 inputs, 2 outputs.
# parse done
# ../benchmarks/core/Num2BitsNeg@bitify@circomlib_64.r1cs
# read done
# 68 constraints, 2 inputs, 64 outputs.
# parse done
# ../benchmarks/core/SMTProcessorSM@smtprocessorsm@circomlib.r1cs
# read done
# 8 constraints, 12 inputs, 6 outputs.
# parse done
# ../benchmarks/core/Pedersen@pedersen_old@circomlib_64.r1cs
# read done
# 1542 constraints, 65 inputs, 2 outputs.
# parse done
# ../benchmarks/core/Pedersen@pedersen_old@circomlib_256.r1cs
# read done
# 6246 constraints, 257 inputs, 2 outputs.
# parse done
# ../benchmarks/core/Pedersen@pedersen_old@circomlib_128.r1cs
# read done
# 3078 constraints, 129 inputs, 2 outputs.
# parse done
# ../benchmarks/core/Point2Bits@pointbits@circomlib.r1cs
# read done
# 0 constraints, 3 inputs, 256 outputs.
# parse done
# ../benchmarks/core/SigmaPlus@sigmaplus@circomlib.r1cs
# read done
# 1027 constraints, 129 inputs, 32 outputs.
# parse done
# ../benchmarks/core/LessEqThan@comparators@circomlib_8.r1cs
# read done
# 15 constraints, 3 inputs, 1 outputs.
# parse done
# ../benchmarks/core/OR@gates@circomlib.r1cs
# read done
# 1 constraints, 3 inputs, 1 outputs.
# parse done
# ../benchmarks/core/Pedersen@pedersen_old@circomlib_32.r1cs
# read done
# 774 constraints, 33 inputs, 2 outputs.
# parse done
# ../benchmarks/core/T1@t1@circomlib.r1cs
# read done
# 772 constraints, 193 inputs, 32 outputs.
# parse done
# ../benchmarks/core/Num2BitsNeg@bitify@circomlib_32.r1cs
# read done
# 36 constraints, 2 inputs, 32 outputs.
# parse done
# ../benchmarks/core/Num2BitsNeg@bitify@circomlib_1.r1cs
# read done
# 5 constraints, 2 inputs, 1 outputs.
# parse done
# ../benchmarks/core/Switcher@switcher@circomlib.r1cs
# read done
# 3 constraints, 4 inputs, 2 outputs.
# parse done
# ../benchmarks/core/Num2BitsNeg@bitify@circomlib_128.r1cs
# read done
# 132 constraints, 2 inputs, 128 outputs.
# parse done
# ../benchmarks/core/Num2BitsNeg@bitify@circomlib_256.r1cs
# read done
# 260 constraints, 2 inputs, 256 outputs.
# parse done
# ../benchmarks/core/Pedersen@pedersen@circomlib_253.r1cs
# read done
# 7614 constraints, 254 inputs, 2 outputs.
# parse done
# ../benchmarks/core/Point2Bits_Strict@pointbits@circomlib.r1cs
# read done
# 2838 constraints, 3 inputs, 256 outputs.
# parse done
# ../benchmarks/core/GreaterEqThan@comparators@circomlib_32.r1cs
# read done
# 39 constraints, 3 inputs, 1 outputs.
# parse done
# ../benchmarks/core/BitElementMulAny@escalarmulany@circomlib.r1cs
# read done
# 24 constraints, 6 inputs, 4 outputs.
# parse done
# ../benchmarks/core/SMTVerifierLevel@smtverifierlevel@circomlib.r1cs
# read done
# 751 constraints, 11 inputs, 1 outputs.
# parse done

# %%
all_d_counts
# Out:
# {3: 19233,
#  2: 185363,
#  1: 8470,
#  4: 44949,
#  6: 3983,
#  5: 13094,
#  9: 6718,
#  128: 43,
#  136: 43,
#  255: 27,
#  7: 209,
#  254: 10,
#  17: 1038,
#  65: 2,
#  10: 4,
#  256: 1,
#  97: 2,
#  33: 2,
#  34: 4,
#  195: 2,
#  49: 1,
#  18: 4,
#  257: 2,
#  129: 2,
#  8: 128,
#  66: 1,
#  162: 1,
#  130: 1,
#  258: 1}

# %%
for max_depth in range(10):
    all_counts = 0
    short_counts = 0
    for k in all_d_counts:
        all_counts += all_d_counts[k]
        if k <= max_depth:
            short_counts += all_d_counts[k]
    print(f"depth {max_depth}", short_counts, all_counts, short_counts/all_counts * 100)
# Out:
# depth 0 0 283338 0.0
# depth 1 8470 283338 2.989362528146595
# depth 2 193833 283338 68.41052029731274
# depth 3 213066 283338 75.19852614192237
# depth 4 258015 283338 91.06261779217753
# depth 5 271109 283338 95.68395344076686
# depth 6 275092 283338 97.08969499325893
# depth 7 275301 283338 97.16345848421321
# depth 8 275429 283338 97.20863421073065
# depth 9 282147 283338 99.5796539821697
