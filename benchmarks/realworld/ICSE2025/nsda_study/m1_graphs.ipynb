# %%
# %flow mode reactive

# %%
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
from matplotlib.legend_handler import HandlerTuple


df = pd.read_csv("../nsda_study_data/ICSE2025_AGGREGATE_DATA.csv")
df['%consistent_result'] = df['%consistent_result'] * 10
df = df.sort_values('id')
df
# Out:
# Matplotlib is building the font cache; this may take a moment.
#       id              tool                     configuration  \
# 0      1         amandroid  116dcfbc705e50820a01593288f9424f
# 1      1         amandroid  b8b8f599206ffee9059479531a3b6287
# 2      1         amandroid  a4209cb5a70c5363bc7f75bd4f586076
# 3      1         amandroid  4672fe4d54a5ee15f1ee35f59479e55c
# 4      2  amandroid-nondex  b8b8f599206ffee9059479531a3b6287
# ...   ..               ...                               ...
# 2245  11              pycg  71288a17962c59c956a333f58d3f97c6
# 2244  11              pycg  71288a17962c59c956a333f58d3f97c6
# 2243  11              pycg  7fdc9fa37279ec83cc35e2644995c580
# 2242  11              pycg  7fdc9fa37279ec83cc35e2644995c580
# 2246  11              pycg  7fdc9fa37279ec83cc35e2644995c580
#
#                                      target  %consistent_result  distribution
# 0     com.angrydoughnuts.android.alarmclock           80.000000             2
# ...

# %%
import seaborn as sb
import matplotlib.pyplot as plt
     
     
tool_set = ['amandroid', 'flowdroid', 'infer', 'soot', 'doop', 'opal', 'code2flow', 'pycg']           
tool_name_set = ['Amandroid', 'FlowDroid', 'Infer', 'Soot', 'DOOP', 'OPAL', 'Code2flow', 'PyCG'] 

fig, axes = plt.subplots(3, 3, figsize=(6.2, 5.7), constrained_layout=True)

axes = axes.flatten()

# Loop through each tool and plot
for i, tool in enumerate(tool_set):
    df_one = df[df['tool'] == tool]
    
    # Create the boxplot and stripplot
    ax = sb.boxplot(
        data=df_one,
        patch_artist=True,
        x='configuration',
        y='%consistent_result',
        hue='tool',
        dodge=False,
        palette=["#66c2a5"],
        ax=axes[i]
    )
    sb.stripplot(
        data=df_one,
        x='configuration',
        y='%consistent_result',
        hue='tool',
        palette=["#478773"],
        dodge=False,
        jitter=False,
        size=4,
        ax=axes[i]
    )
    
    y_min = int(df_one['%consistent_result'].min())
    y_max = int(df_one['%consistent_result'].max()) + 1
    ax.set_ylim(y_min, y_max)

    ax.legend().remove()
    ax.set(xticklabels=[])
    ax.set_xlabel(f'{tool_name_set[i]} Configs', fontsize=12)
    ax.set_ylabel('% Consistent Results', fontsize=12)
    # ax.grid(True, axis='y', linestyle='--', linewidth=0.5)
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])
    
plt.savefig('ICSE2025_Consistency.pdf', dpi=300, format='pdf', bbox_inches='tight')
plt
# Out:
# <module 'matplotlib.pyplot' from '/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/pyplot.py'>

# %%
import seaborn as sb
import matplotlib.pyplot as plt
     
     
tool_set = ['amandroid-nondex', 'flowdroid-nondex', 'soot-nondex']           
tool_name_set = ['Amandroid', 'FlowDroid', 'Soot'] 

fig, axes = plt.subplots(1, 3, figsize=(6.2, 1.9), constrained_layout=True)

axes = axes.flatten()

# Loop through each tool and plot
for i, tool in enumerate(tool_set):
    df_one = df[df['tool'] == tool]
    
    # Create the boxplot and stripplot
    ax = sb.boxplot(
        data=df_one,
        patch_artist=True,
        x='configuration',
        y='%consistent_result',
        hue='tool',
        dodge=False,
        palette=["#fc8d62"],
        ax=axes[i]
    )
    sb.stripplot(
        data=df_one,
        x='configuration',
        y='%consistent_result',
        hue='tool',
        palette=["#b06344"],
        dodge=False,
        jitter=False,
        size=4,
        ax=axes[i]
    )
    
    y_min = int(df_one['%consistent_result'].min())
    y_max = int(df_one['%consistent_result'].max()) + 1
    ax.set_ylim(y_min, y_max)

    ax.legend().remove()
    ax.set(xticklabels=[])
    ax.set_xlabel(f'{tool_name_set[i]} Configs', fontsize=12)
    ax.set_ylabel('% Consistent Results', fontsize=12)
    # ax.grid(True, axis='y', linestyle='--', linewidth=0.5)
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])
    
plt.savefig('ICSE2025_Consistency_II.pdf', dpi=300, format='pdf', bbox_inches='tight')
plt
# Out:
# <module 'matplotlib.pyplot' from '/home/miao/ND_Detector/ndvenv/lib/python3.8/site-packages/matplotlib/pyplot.py'>

# %%
tool_set = ['amandroid', 'flowdroid', 'infer', 'soot', 'doop', 'opal', 'code2flow', 'pycg']           
tool_name_set = ['Amandroid', 'FlowDroid', 'Infer', 'Soot', 'DOOP', 'OPAL', 'Code2flow', 'PyCG'] 

fig, axes = plt.subplots(3, 3, figsize=(6.2, 5.7), constrained_layout=True)

axes = axes.flatten()

# Loop through each tool and plot
for i, tool in enumerate(tool_set):
    df_one = df[df['tool'] == tool]
    
    # Create the boxplot and stripplot
    ax = sb.boxplot(
        data=df_one,
        patch_artist=True,
        x='configuration',
        y='distribution',
        hue='tool',
        dodge=False,
        palette=["#66c2a5"],
        ax=axes[i]
    )
    sb.stripplot(
        data=df_one,
        x='configuration',
        y='distribution',
        hue='tool',
        palette=["#478773"],
        dodge=False,
        jitter=False,
        size=4,
        ax=axes[i]
    )
    
    ax.set_ylim(2, 6)

    ax.legend().remove()
    ax.set(xticklabels=[])
    ax.set_xlabel(f'{tool_name_set[i]} Configs', fontsize=12)
    ax.set_ylabel('# of Distinct Results', fontsize=12)
    # ax.grid(True, axis='y', linestyle='--', linewidth=0.5)
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])
    
plt.savefig('ICSE2025_Distribution.pdf', dpi=300, format='pdf', bbox_inches='tight')
plt
# Out:
# <module 'matplotlib.pyplot' from '/home/miao/ND_Detector/ndvenv/lib/python3.8/site-packages/matplotlib/pyplot.py'>

# %%
tool_set = ['amandroid-nondex', 'flowdroid-nondex', 'soot-nondex']           
tool_name_set = ['Amandroid', 'FlowDroid', 'Soot'] 

fig, axes = plt.subplots(1, 3, figsize=(6.2, 1.9), constrained_layout=True)

axes = axes.flatten()

# Loop through each tool and plot
for i, tool in enumerate(tool_set):
    df_one = df[df['tool'] == tool]
    
    # Create the boxplot and stripplot
    ax = sb.boxplot(
        data=df_one,
        patch_artist=True,
        x='configuration',
        y='distribution',
        hue='tool',
        dodge=False,
        palette=["#fc8d62"],
        ax=axes[i]
    )
    sb.stripplot(
        data=df_one,
        x='configuration',
        y='distribution',
        hue='tool',
        palette=["#b06344"],
        dodge=False,
        jitter=False,
        size=4,
        ax=axes[i]
    )
    
    ax.set_ylim(2, 6)

    ax.legend().remove()
    ax.set(xticklabels=[])
    ax.set_xlabel(f'{tool_name_set[i]} Configs', fontsize=12)
    ax.set_ylabel('# of Distinct Results', fontsize=12)
    # ax.grid(True, axis='y', linestyle='--', linewidth=0.5)
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])
    
plt.savefig('ICSE2025_Distribution_II.pdf', dpi=300, format='pdf', bbox_inches='tight')
plt
# Out:
# <module 'matplotlib.pyplot' from '/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/pyplot.py'>
