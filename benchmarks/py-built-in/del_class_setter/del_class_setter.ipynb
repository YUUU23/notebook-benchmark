# %%
class my_class:
    a = None 
    def __init__(self, val):
        self.a = val
    def get_a(self): 
        return self.a 
    def set_a(self, val):
        self.a = val

# %%
c_1 = my_class(3)
print(c_1.get_a())
# Out:
# 3

# %%
c_1.set_a(123)

# %%
print(c_1.get_a())
# Out:
# 10
