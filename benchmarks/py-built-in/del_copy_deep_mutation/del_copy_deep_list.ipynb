# %%
import copy
# Out:
# [rnb 16:59:56.790]   DAG transitivity: exec id 12 [32ff78] is mutation; preserving existing edges

# %%
ll = [[1],[2],[3]]
# Out:
# [rnb 16:59:56.796] ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# [rnb 16:59:56.797] Exec 13 [44c929] starting
# [rnb 16:59:56.797]   Code:  ll = [[1],[2],[3]]
# [rnb 16:59:56.798]   DB:    data/del_copy_deep_list/20260625_165900/trace.db
# [rnb 16:59:56.798]   Log:   data/del_copy_deep_list/20260625_165900/log
# [rnb 16:59:57.165] Exec 13 [44c929] done in 42.7 ms
# [rnb 16:59:57.165]   Live allocations: 93 buffers (389,120 bytes total)
# [rnb 16:59:57.166]   Faults this cell: 28 reads, 0 writes (28 unique fault addrs)
# [rnb 16:59:57.166]   Memcpy records:   49005
# [rnb 16:59:57.250]   Memory deps: exec id 13 [44c929] has no cross-cell buffer reads
# [rnb 16:59:57.251]   DAG transitivity: exec id 13 [44c929] is mutation; preserving existing edges

# %%
c_l = copy.deepcopy(ll)
# Out:
# [rnb 16:59:57.257] ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# [rnb 16:59:57.258] Exec 14 [c63da2] starting
# [rnb 16:59:57.258]   Code:  c_l = copy.deepcopy(ll)
# [rnb 16:59:57.258]   DB:    data/del_copy_deep_list/20260625_165900/trace.db
# [rnb 16:59:57.259]   Log:   data/del_copy_deep_list/20260625_165900/log
# [rnb 16:59:57.557] Exec 14 [c63da2] done in 16.3 ms
# [rnb 16:59:57.558]   Live allocations: 93 buffers (389,120 bytes total)
# [rnb 16:59:57.559]   Faults this cell: 49 reads, 0 writes (49 unique fault addrs)
# [rnb 16:59:57.559]   Memcpy records:   28892
# [rnb 16:59:57.619]   Memory deps: exec id 14 [c63da2] has no cross-cell buffer reads
# [rnb 16:59:57.620]   DAG transitivity: exec id 14 [c63da2] is mutation; preserving existing edges

# %%
c_l[0].append(10)
# Out:
# [rnb 17:00:09.706]   DAG transitivity: exec id 17 [8fa655] writes=[], mutated_syms=[]

# %%
print(c_l)
# Out:
# [[1, 10], [2], [3]]
# [rnb 17:00:10.001]   DAG transitivity: exec id 18 [086f66] is mutation; preserving existing edges

# %%
print(ll)
# Out:
# [[1], [2], [3]]
# [rnb 16:59:57.655]   DAG transitivity: exec id 16 [84f0c0] is mutation; preserving existing edges
