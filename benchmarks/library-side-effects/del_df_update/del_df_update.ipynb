# %%
import pandas as pd
# Out:
# [rnb 17:59:54.117]   DAG transitivity: exec id 7 [6b37ae] is mutation; preserving existing edges

# %%
df1 = pd.DataFrame({
    'A': [1, 2, 3],
    'B': [4, 5, 6]
})
# Out:
# [rnb 17:59:54.123] ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# [rnb 17:59:54.124] Exec 8 [758430] starting
# [rnb 17:59:54.124]   Code:  df1 = pd.DataFrame({ ↵     'A': [1, 2, 3], ↵     'B': [4, 5, 6] ↵ })
# [rnb 17:59:54.125]   DB:    data/del_df_update/20260625_175945/trace.db
# [rnb 17:59:54.125]   Log:   data/del_df_update/20260625_175945/log
# [rnb 17:59:54.524] Exec 8 [758430] done in 43.8 ms
# [rnb 17:59:54.525]   Live allocations: 180 buffers (737,280 bytes total)
# [rnb 17:59:54.526]   Faults this cell: 62 reads, 8 writes (70 unique fault addrs)
# [rnb 17:59:54.526]   Memcpy records:   64898
# [rnb 17:59:54.634]   Memory deps: exec id 8 [758430] has no cross-cell buffer reads
# [rnb 17:59:54.635]   DAG transitivity: exec id 8 [758430] is mutation; preserving existing edges

# %%
df2 = pd.DataFrame({
    'A': [200, 200, 200],
    'B': [200, 200, 200]
})
# Out:
# [rnb 17:59:54.642] ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# [rnb 17:59:54.643] Exec 9 [7bf297] starting
# [rnb 17:59:54.643]   Code:  df2 = pd.DataFrame({ ↵     'A': [200, 200, 200], ↵     'B': [200, 200, 200] ↵ })
# [rnb 17:59:54.644]   DB:    data/del_df_update/20260625_175945/trace.db
# [rnb 17:59:54.644]   Log:   data/del_df_update/20260625_175945/log
# [rnb 17:59:55.029] Exec 9 [7bf297] done in 32.3 ms
# [rnb 17:59:55.030]   Live allocations: 194 buffers (794,624 bytes total)
# [rnb 17:59:55.031]   Faults this cell: 67 reads, 12 writes (79 unique fault addrs)
# [rnb 17:59:55.031]   Memcpy records:   65870
# [rnb 17:59:55.149]   Memory deps: exec id 9 [7bf297] ← exec ids [2 [758430]] (last writers of read buffers)
# [rnb 17:59:55.150]   DAG transitivity: exec id 9 [7bf297] is mutation; preserving existing edges

# %%
df2['A'] = [200,None,200]
# Out:
# [rnb 17:59:55.156] ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# [rnb 17:59:55.157] Exec 10 [da3481] starting
# [rnb 17:59:55.157]   Code:  df2['A'] = [200,None,200]
# [rnb 17:59:55.158]   DB:    data/del_df_update/20260625_175945/trace.db
# [rnb 17:59:55.158]   Log:   data/del_df_update/20260625_175945/log
# [rnb 17:59:55.474] Exec 10 [da3481] done in 18.0 ms
# [rnb 17:59:55.475]   Live allocations: 182 buffers (745,472 bytes total)
# [rnb 17:59:55.475]   Faults this cell: 58 reads, 19 writes (77 unique fault addrs)
# [rnb 17:59:55.476]   Memcpy records:   32973
# [rnb 17:59:55.545]   Memory deps: exec id 10 [da3481] ← exec ids [9 [7bf297]] (last writers of read buffers)
# [rnb 17:59:55.546]   DAG transitivity: exec id 10 [da3481] is mutation; preserving existing edges

# %%
df1.update(df2)

# %%
print(df1)
# Out:
#    A  B
# 0  1  4
# 1  2  5
# 2  3  6
# [rnb 17:59:55.561]   DAG transitivity: exec id 11 [d4596b] is mutation; preserving existing edges
