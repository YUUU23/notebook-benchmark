# %%
import numpy as np
# Out:
# [rnb 18:04:08.814]   DAG transitivity: exec id 6 [ffe4c5] is mutation; preserving existing edges

# %%
a = np.array([1,2,3,4])
# Out:
# [rnb 18:04:08.823] ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# [rnb 18:04:08.824] Exec 7 [9586d6] starting
# [rnb 18:04:08.824]   Code:  a = np.array([1,2,3,4])
# [rnb 18:04:08.825]   DB:    data/del_numpy_place/20260625_180402/trace.db
# [rnb 18:04:08.825]   Log:   data/del_numpy_place/20260625_180402/log
# [rnb 18:04:09.178] Exec 7 [9586d6] done in 54.0 ms
# [rnb 18:04:09.179]   Live allocations: 62 buffers (262,144 bytes total)
# [rnb 18:04:09.179]   Faults this cell: 41 reads, 1 writes (42 unique fault addrs)
# [rnb 18:04:09.180]   Memcpy records:   37880
# [rnb 18:04:09.244]   Memory deps: exec id 7 [9586d6] has no cross-cell buffer reads
# [rnb 18:04:09.245]   DAG transitivity: exec id 7 [9586d6] is mutation; preserving existing edges

# %%
pred = a % 2 == 0
# Out:
# [rnb 18:04:09.250] ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# [rnb 18:04:09.251] Exec 8 [4f8ace] starting
# [rnb 18:04:09.251]   Code:  pred = a % 2 == 0
# [rnb 18:04:09.252]   DB:    data/del_numpy_place/20260625_180402/trace.db
# [rnb 18:04:09.252]   Log:   data/del_numpy_place/20260625_180402/log
# [rnb 18:04:09.525] Exec 8 [4f8ace] done in 10.8 ms
# [rnb 18:04:09.525]   Live allocations: 59 buffers (258,048 bytes total)
# [rnb 18:04:09.526]   Faults this cell: 23 reads, 3 writes (26 unique fault addrs)
# [rnb 18:04:09.526]   Memcpy records:   16641
# [rnb 18:04:09.568]   Memory deps: exec id 8 [4f8ace] ← exec ids [7 [9586d6]] (last writers of read buffers)
# [rnb 18:04:09.569]   DAG transitivity: exec id 8 [4f8ace] is mutation; preserving existing edges

# %%
np.place(a, pred, [20,40,60,80])

# %%
print(a)
# Out:
# [1 2 3 4]
# [rnb 18:04:09.582]   DAG transitivity: exec id 9 [71db73] is mutation; preserving existing edges
